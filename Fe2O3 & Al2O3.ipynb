# %%
# import packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# import the data 
df = pd.read_excel('new.xlsx')
#showing the data
print (" Analyse the variation of Al2O3 & Fe2O3 with Depth \n so this the data provided to work on ")
print(df)
## refering the data

iron = df['Fe203 %']
Alu = df['Al203 %']
depth = df['Depth']

## calculating the mean and the median for iron

mean_iron = np.mean(iron)
median_iron = np.median (iron)
print(f'\nThe mean of Fe2O3 = {mean_iron} ' '\n' f'The median of Fe2O3 = {mean_iron}')

## creating classes 

num_classes = 7
data_range = iron.max() - iron.min()
class_width = data_range / num_classes
bins = [iron.min() + i * class_width for i in range(num_classes + 1)]

## calculating the mean and the median for Alumunium

mean_Alu = np.mean(Alu)
median_Alu = np.median (Alu)
print('\n'f'The mean of Al2O3 = {mean_Alu} ' '\n' f'The median of Al2O3 = {median_Alu}')


## frequency table
print("\nThe Frequecy table :" , frequency_table, _)
frequency_table, _= np.histogram(iron , bins = 7)

#cummulative frequency
cumm = np.cumsum(frequency_table)
print(f"The cummulative frequency : {cumm}")

## histogram 
plt.figure(figsize=(10, 6))
plt.bar(range(num_classes), cumm, width=1, edgecolor='black')
plt.xlabel('Classes')
plt.ylabel('Cumulative Frequency')
plt.title('Histogram of Cumulative Frequency for Iron oxide')
plt.xticks(range(num_classes), bins[:-1])
plt.grid(True)
plt.show()

# Fe2O3 & Al2O3 against depth
plt.figure(figsize=(10, 6))
plt.scatter(depth  , iron, label =  'Fe2O3' )
plt.scatter (depth , Alu, label = 'Al2O3')
plt.xlabel('Depth (m)')
plt.ylabel('Concentraion %')
plt.legend()
plt.title('Fe2O3 % & Al2O3 % against depth')
# Out:
#  Analyse the variation of Al2O3 & Fe2O3 with Depth
#  so this the data provided to work on
#     Depth  Fe203 %  Al203 %
# 0     0.0    24.80    45.01
# 1     0.5    22.00    48.69
# 2     1.0    19.80    49.93
# 3     1.5    27.80    45.17
# 4     2.0    25.80    43.77
# 5     2.5    23.00    48.69
# 6     3.0    34.00    39.38
# 7     3.5    29.60    42.26
# 8     4.0    31.80    32.40
# 9     4.5    35.80    33.53
# 10    5.0    40.40    31.74
# 11    5.5    40.00    32.68
# 12    6.0    15.20    32.56
# 13    6.5    17.60    49.98
# 14    7.0    24.20    45.83
# 15    7.5    19.40     4.69
# 16    8.0    35.30    33.95
# 17    8.5    31.40    39.02
# 18    9.0    28.21    32.52
# 19    9.5    34.00    39.02
# 20   10.0    34.00    39.02
# 21   10.5    21.80    43.45
# 22   11.0    25.60    42.58
# 23   11.5    32.40    38.72
# 24   12.0    27.40    42.92
# 25   12.5    25.80    43.89
# 26   13.0    31.40    38.13
# 27   13.5    27.80    42.92
# 28   14.0    24.40    46.13
# 29   14.5    25.60    44.85
# 30   15.0    23.80    44.85
# 31   15.5    21.60    47.41
# 32   16.0    27.60    44.53
# 33   16.5    19.80    48.05
# 34   17.0    27.80    44.21
# 35   17.5    21.20    48.70
# 36   18.0    19.00    49.34
# 37   18.5    28.60    44.21
# 38   19.0    24.80    45.49
# 39   19.5    23.40    46.99
# 40   20.0    17.80    49.66
# 41   20.5    24.60    45.49
# 42   21.0    21.40    48.03
# 43   21.5    24.00    45.49
# 44   22.0    26.00    44.05
# 45   22.5    19.00    49.02
# 46   23.0    24.00    32.34
# 47   23.5    15.60    41.90
# 48   24.0    19.20    47.11
# 49   24.5    17.80    48.70
# 50   25.0    21.20    46.77
# 51   25.5    30.00    49.39
# 52   26.0    23.60    45.01
# 53   26.5    25.20    42.62
# 54   27.0    17.20    50.20
# 55   27.5    20.60    48.13
# 56   28.0    25.00    43.23
# 57   28.5    18.00    56.88
# 58   29.0    25.00    44.20
# 59   29.5    21.40    46.77
#
# The mean of Fe2O3 = 25.17516666666667
# The median of Fe2O3 = 25.17516666666667
#
# The mean of Al2O3 = 43.03666666666666
# The median of Al2O3 = 44.69
#
# The Frequecy table : [ 7 14 18  8  6  5  2] [15.2 18.8 22.4 26.  29.6 33.2 36.8 40.4]
# The cummulative frequency : [ 7 21 39 47 53 58 60]
# Text(0.5, 1.0, 'Fe2O3 % & Al2O3 % against depth')
